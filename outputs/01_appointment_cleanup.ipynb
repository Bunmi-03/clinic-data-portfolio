# %% [markdown]
# # P1 — Cedar Dental: Appointment Register Cleanup
# **Scenario:** Cedar Dental has exported 515 appointment records. The data has missing values,
# duplicate rows, and inconsistent appointment type labels. This notebook cleans the dataset
# and produces a client-ready output file.
#
# **Input:** `appointments_raw.csv`
# **Output:** `appointments_cleaned_YYYYMMDD.csv`
# **Libraries:** pandas only

# %%
import pandas as pd
from datetime import datetime #  imports the datetime class from Python's built-in datetime module

df = pd.read_csv(r"C:\Users\clemo\Downloads\appointments_raw.csv")
df
# Out:
#     appointment_id patient_id appointment_date appointment_type     therapist  \
# 0          APT0001      P0013       15/10/2024          Filling     Dr. Patel
# 1          APT0002      P0053       20/09/2024           Chekup           NaN
# 2          APT0003        NaN       05/02/2024       extraction     Dr. Patel
# 3          APT0004      P0367       09/09/2024            Clean     Dr. Patel
# 4          APT0005      P0004       22/10/2024       Extraction  Dr. Williams
# ..             ...        ...              ...              ...           ...
# 510        APT0323      P0045       26/01/2024          filling  Dr. Williams
# 511        APT0169      P0123       10/08/2024         cleaning     Dr. Patel
# 512        APT0120      P0375       18/08/2024          Filling    Dr. Nguyen
# 513        APT0067      P0342       09/02/2024         Cleaning           NaN
# 514        APT0306      P0165       09/02/2024           Chekup    Dr. Nguyen
#
#     attended
# 0         no
# 1          0
# 2        Yes
# 3        NaN
# 4          1
# ..       ...
# 510      NaN
# 511        0
# 512       no
# 513        0
# 514      YES
#
# [515 rows x 6 columns]

# %% [markdown]
# ## 1. Data Inspection

# %%
# Finding the shape of the dataframe
print("Shape:", df.shape)
# Out:
# Shape: (515, 6)

# %%
# Finding the datatypes of each set of data in the columns
print("Column types:")
print(df.dtypes)
# Out:
# Column types:
# appointment_id      object
# patient_id          object
# appointment_date    object
# appointment_type    object
# therapist           object
# attended            object
# dtype: object

# %%
# Finds the null values in each data set
print("Null counts:")
print(df.isnull().sum())
# Out:
# Null counts:
# appointment_id        0
# patient_id           20
# appointment_date      0
# appointment_type      0
# therapist           102
# attended             76
# dtype: int64

# %%
# Finds the sum of the duplicated values in each row
print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 15

# %% [markdown]
# ## 2. Fix: Drop duplicate Rows

# %%
## Finds all the duplicate values
df[df.duplicated()]
# Out:
#     appointment_id patient_id appointment_date appointment_type     therapist  \
# 500        APT0305      P0373       14/06/2024           Chekup  Dr. Williams
# 501        APT0341      P0082       12/11/2024           Fillig           NaN
# 502        APT0048      P0245       14/07/2024          Consult     Dr. Patel
# 503        APT0068      P0384       01/03/2024       EXTRACTION     Dr. Patel
# 504        APT0480      P0248       10/02/2024          filling  Dr. Williams
# 505        APT0486      P0170       05/08/2024            Clean  Dr. Williams
# 506        APT0311      P0399       08/09/2024         Cleaning    Dr. Nguyen
# 507        APT0032      P0333       25/05/2024     Consultation           NaN
# 508        APT0250      P0055       04/04/2024            Clean           NaN
# 509        APT0091      P0357       20/07/2024     Consultation     Dr. Ahmed
# 510        APT0323      P0045       26/01/2024          filling  Dr. Williams
# 511        APT0169      P0123       10/08/2024         cleaning     Dr. Patel
# 512        APT0120      P0375       18/08/2024          Filling    Dr. Nguyen
# 513        APT0067      P0342       09/02/2024         Cleaning           NaN
# 514        APT0306      P0165       09/02/2024           Chekup    Dr. Nguyen
#
#     attended
# 500      yes
# 501        1
# 502      Yes
# 503      yes
# 504       No
# 505       no
# 506        0
# 507      NaN
# 508        0
# 509       no
# 510      NaN
# 511        0
# 512       no
# 513        0
# 514      YES

# %%
## Drops/Removes all the duplicate values
df = df.drop_duplicates().copy()

# %%
df
# Out:
#     appointment_id patient_id appointment_date appointment_type     therapist  \
# 0          APT0001      P0013       15/10/2024          Filling     Dr. Patel
# 1          APT0002      P0053       20/09/2024           Chekup           NaN
# 2          APT0003        NaN       05/02/2024       extraction     Dr. Patel
# 3          APT0004      P0367       09/09/2024            Clean     Dr. Patel
# 4          APT0005      P0004       22/10/2024       Extraction  Dr. Williams
# ..             ...        ...              ...              ...           ...
# 495        APT0496      P0295       29/05/2024            Clean     Dr. Patel
# 496        APT0497      P0356       24/12/2024       Extraction           NaN
# 497        APT0498      P0072       13/03/2024           Fillig  Dr. Williams
# 498        APT0499      P0005       07/07/2024         Check Up     Dr. Patel
# 499        APT0500      P0259       11/09/2024     consultation  Dr. Williams
#
#     attended
# 0         no
# 1          0
# 2        Yes
# 3        NaN
# 4          1
# ..       ...
# 495      NaN
# 496      yes
# 497      Yes
# 498        0
# 499      NaN
#
# [500 rows x 6 columns]

# %%
## Now we have removed all duplicate values from our dataframe
print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %% [markdown]
# ## 3. Fix appointment_type - Standardise Labels

# %%
# Step 1: normalise casing and whitespace first
df['appointment_type'] = df['appointment_type'].str.lower().str.strip()
df
# Out:
#     appointment_id patient_id appointment_date appointment_type     therapist  \
# 0          APT0001      P0013       15/10/2024          filling     Dr. Patel
# 1          APT0002      P0053       20/09/2024           chekup           NaN
# 2          APT0003        NaN       05/02/2024       extraction     Dr. Patel
# 3          APT0004      P0367       09/09/2024            clean     Dr. Patel
# 4          APT0005      P0004       22/10/2024       extraction  Dr. Williams
# ..             ...        ...              ...              ...           ...
# 495        APT0496      P0295       29/05/2024            clean     Dr. Patel
# 496        APT0497      P0356       24/12/2024       extraction           NaN
# 497        APT0498      P0072       13/03/2024           fillig  Dr. Williams
# 498        APT0499      P0005       07/07/2024         check up     Dr. Patel
# 499        APT0500      P0259       11/09/2024     consultation  Dr. Williams
#
#     attended
# 0         no
# 1          0
# 2        Yes
# 3        NaN
# 4          1
# ..       ...
# 495      NaN
# 496      yes
# 497      Yes
# 498        0
# 499      NaN
#
# [500 rows x 6 columns]

# %%
# Step 2: check what you're working with after normalisation
print(df['appointment_type'].value_counts())
# Out:
# appointment_type
# extraction      75
# filling         69
# consultation    69
# cleaning        54
# fillig          39
# check-up        37
# check up        35
# chekup          34
# clean           33
# consult         30
# checkup         25
# Name: count, dtype: int64

# %%
 # Step 3: map dirty variants to 5 clean labels
correct_map = {
    'filling':  'filling',
    'fillig':        'filling',    # typo
    'check-up':      'check-up',
    'checkup':       'check-up',
    'check up':      'check-up',
    'chekup':        'check-up',   # typo
    'cleaning':      'cleaning',
    'clean':         'cleaning',
    'extraction':    'extraction',
    'consultation':  'consultation',
    'consult':       'consultation'
}

df['appointment_type'] = df['appointment_type'].map(correct_map)
df
# Out:
#     appointment_id patient_id appointment_date appointment_type     therapist  \
# 0          APT0001      P0013       15/10/2024          filling     Dr. Patel
# 1          APT0002      P0053       20/09/2024         check-up           NaN
# 2          APT0003        NaN       05/02/2024       extraction     Dr. Patel
# 3          APT0004      P0367       09/09/2024         cleaning     Dr. Patel
# 4          APT0005      P0004       22/10/2024       extraction  Dr. Williams
# ..             ...        ...              ...              ...           ...
# 495        APT0496      P0295       29/05/2024         cleaning     Dr. Patel
# 496        APT0497      P0356       24/12/2024       extraction           NaN
# 497        APT0498      P0072       13/03/2024          filling  Dr. Williams
# 498        APT0499      P0005       07/07/2024         check-up     Dr. Patel
# 499        APT0500      P0259       11/09/2024     consultation  Dr. Williams
#
#     attended
# 0         no
# 1          0
# 2        Yes
# 3        NaN
# 4          1
# ..       ...
# 495      NaN
# 496      yes
# 497      Yes
# 498        0
# 499      NaN
#
# [500 rows x 6 columns]

# %%
# Step 4: verify — should be 0 nulls and exactly 5 unique values
print(df['appointment_type'].value_counts()) 
print("Unmapped (nulls introduced):", df['appointment_type'].isnull().sum())
# Out:
# appointment_type
# check-up        131
# filling         108
# consultation     99
# cleaning         87
# extraction       75
# Name: count, dtype: int64
# Unmapped (nulls introduced): 0

# %% [markdown]
# ## 4. Fix: appointment_date — Parse to datetime

# %%
# Standardise the dates and if you cannot parse a date then turn it into NaT
df['appointment_date'] = pd.to_datetime(df['appointment_date'], dayfirst=True, errors='coerce')
# Check how many bad dates got nulled out
print(df['appointment_date'].isnull().sum())
# Out:
# 1

# %%
# pd.to_datetime() converts dates into a full datetime object — date and time. Since your data has no time information, it just fills the time part with 00:00:00 as a default.
# If we want clean dates only then:
df['appointment_date'] = df['appointment_date'].dt.date
df
# Out:
#     appointment_id patient_id appointment_date appointment_type     therapist  \
# 0          APT0001      P0013       2024-10-15          filling     Dr. Patel
# 1          APT0002      P0053       2024-09-20         check-up           NaN
# 2          APT0003        NaN       2024-02-05       extraction     Dr. Patel
# 3          APT0004      P0367       2024-09-09         cleaning     Dr. Patel
# 4          APT0005      P0004       2024-10-22       extraction  Dr. Williams
# ..             ...        ...              ...              ...           ...
# 495        APT0496      P0295       2024-05-29         cleaning     Dr. Patel
# 496        APT0497      P0356       2024-12-24       extraction           NaN
# 497        APT0498      P0072       2024-03-13          filling  Dr. Williams
# 498        APT0499      P0005       2024-07-07         check-up     Dr. Patel
# 499        APT0500      P0259       2024-09-11     consultation  Dr. Williams
#
#     attended
# 0         no
# 1          0
# 2        Yes
# 3        NaN
# 4          1
# ..       ...
# 495      NaN
# 496      yes
# 497      Yes
# 498        0
# 499      NaN
#
# [500 rows x 6 columns]

# %%
# attended column has: yes, YES, Yes, 1, no, No, 0
print(df['attended'].value_counts())
# Out:
# attended
# 0      68
# yes    62
# no     61
# 1      61
# Yes    59
# YES    58
# No     57
# Name: count, dtype: int64

# %%
bool_map = {
    '0':  False,
    'yes' : True,
    'no': False,
    '1': True,
    'Yes': True,
    'YES': True,
    'No': False}

df['attended'] = df['attended'].map(bool_map)
df
# Out:
#     appointment_id patient_id appointment_date appointment_type     therapist  \
# 0          APT0001      P0013       2024-10-15          filling     Dr. Patel
# 1          APT0002      P0053       2024-09-20         check-up           NaN
# 2          APT0003        NaN       2024-02-05       extraction     Dr. Patel
# 3          APT0004      P0367       2024-09-09         cleaning     Dr. Patel
# 4          APT0005      P0004       2024-10-22       extraction  Dr. Williams
# ..             ...        ...              ...              ...           ...
# 495        APT0496      P0295       2024-05-29         cleaning     Dr. Patel
# 496        APT0497      P0356       2024-12-24       extraction           NaN
# 497        APT0498      P0072       2024-03-13          filling  Dr. Williams
# 498        APT0499      P0005       2024-07-07         check-up     Dr. Patel
# 499        APT0500      P0259       2024-09-11     consultation  Dr. Williams
#
#     attended
# 0      False
# 1      False
# 2       True
# 3        NaN
# 4       True
# ..       ...
# 495      NaN
# 496     True
# 497     True
# 498    False
# 499      NaN
#
# [500 rows x 6 columns]

# %% [markdown]
# ## 5. Fix: patient_id — Flag Missing Records

# %%
# Creating a new column called record_status. 'Incomplete' if pateient_id is null, therapist is null and attended is null. 'Complete' everywhere else
df['record_status'] = df.apply(
    lambda row: 'Incomplete' 
    if pd.isnull(row['patient_id']) or pd.isnull(row['therapist']) or pd.isnull(row['attended'])
    else 'Complete', axis=1
)


# To verify this
print(df['record_status'].value_counts())
# Out:
# record_status
# Complete      324
# Incomplete    176
# Name: count, dtype: int64

# %%
df
# Out:
#     appointment_id patient_id appointment_date appointment_type     therapist  \
# 0          APT0001      P0013       2024-10-15          filling     Dr. Patel
# 1          APT0002      P0053       2024-09-20         check-up           NaN
# 2          APT0003        NaN       2024-02-05       extraction     Dr. Patel
# 3          APT0004      P0367       2024-09-09         cleaning     Dr. Patel
# 4          APT0005      P0004       2024-10-22       extraction  Dr. Williams
# ..             ...        ...              ...              ...           ...
# 495        APT0496      P0295       2024-05-29         cleaning     Dr. Patel
# 496        APT0497      P0356       2024-12-24       extraction           NaN
# 497        APT0498      P0072       2024-03-13          filling  Dr. Williams
# 498        APT0499      P0005       2024-07-07         check-up     Dr. Patel
# 499        APT0500      P0259       2024-09-11     consultation  Dr. Williams
#
#     attended record_status
# 0      False      Complete
# 1      False    Incomplete
# 2       True    Incomplete
# 3        NaN    Incomplete
# 4       True      Complete
# ..       ...           ...
# 495      NaN    Incomplete
# 496     True    Incomplete
# 497     True      Complete
# 498    False      Complete
# 499      NaN    Incomplete
#
# [500 rows x 7 columns]

# %%
# attended column has: yes, YES, Yes, 1, no, No, NO, 0
print(df['attended'].value_counts())
# Out:
# attended
# True     240
# False    186
# Name: count, dtype: int64

# %%
df
# Out:
#     appointment_id patient_id appointment_date appointment_type     therapist  \
# 0          APT0001      P0013       2024-10-15          filling     Dr. Patel
# 1          APT0002      P0053       2024-09-20         check-up           NaN
# 2          APT0003        NaN       2024-02-05       extraction     Dr. Patel
# 3          APT0004      P0367       2024-09-09         cleaning     Dr. Patel
# 4          APT0005      P0004       2024-10-22       extraction  Dr. Williams
# ..             ...        ...              ...              ...           ...
# 495        APT0496      P0295       2024-05-29         cleaning     Dr. Patel
# 496        APT0497      P0356       2024-12-24       extraction           NaN
# 497        APT0498      P0072       2024-03-13          filling  Dr. Williams
# 498        APT0499      P0005       2024-07-07         check-up     Dr. Patel
# 499        APT0500      P0259       2024-09-11     consultation  Dr. Williams
#
#     attended record_status
# 0      False      Complete
# 1      False    Incomplete
# 2       True    Incomplete
# 3        NaN    Incomplete
# 4       True      Complete
# ..       ...           ...
# 495      NaN    Incomplete
# 496     True    Incomplete
# 497     True      Complete
# 498    False      Complete
# 499      NaN    Incomplete
#
# [500 rows x 7 columns]

# %% [markdown]
# ## 6. Export Cleaned File

# %%
today = datetime.today().strftime('%Y%m%d')
output_path = f'../outputs/appointments_cleaned_{today}.csv'
df.to_csv(output_path, index=False)
print(f"Exported: {output_path}")
print(f"Final shape: {df.shape}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[23], line 3
#       1 today = datetime.today().strftime('%Y%m%d')
#       2 output_path = f'../outputs/appointments_cleaned_{today}.csv'
# ----> 3 df.to_csv(output_path, index=False)
#       4 print(f"Exported: {output_path}")
#       5 print(f"Final shape: {df.shape}")
#
# File c:\Users\clemo\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\clemo\anaconda3\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\Users\clemo\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\clemo\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\clemo\anaconda3\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File c:\Users\clemo\anaconda3\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '..\outputs'
